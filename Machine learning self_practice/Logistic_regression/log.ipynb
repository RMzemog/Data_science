# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('5.2 Example_bank_data.csv')
df.head()
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.isnull().sum()
df.y = df.y.map({'yes' : 1, 'no':0})

# %%
X = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=99)

# %%
from sklearn.linear_model import LogisticRegression 
classfier = LogisticRegression()
classfier.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
print(classfier.predict([[85]]))
# Out:
# [0]

# %%
plt.figure(figsize=(20,8))
plt.scatter(X_test,y_test,color='g',marker='*')
plt.scatter(X_test,classfier.predict(X_test),marker='.')

# %%
classfier.score(X_test,y_test)
# Out:
# 0.6826923076923077

# %%
df2 = pd.read_csv('8.1 Bank_data.csv')
df2.head()
# Out:
#    Unnamed: 0  interest_rate  credit  march  may  previous  duration    y
# 0           0          1.334     0.0    1.0  0.0       0.0     117.0   no
# 1           1          0.767     0.0    0.0  2.0       1.0     274.0  yes
# 2           2          4.858     0.0    1.0  0.0       0.0     167.0   no
# 3           3          4.120     0.0    0.0  0.0       0.0     686.0  yes
# 4           4          4.856     0.0    1.0  0.0       0.0     157.0   no

# %%
df2.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df2.head()
# Out:
#    interest_rate  credit  march  may  previous  duration    y
# 0          1.334     0.0    1.0  0.0       0.0     117.0   no
# 1          0.767     0.0    0.0  2.0       1.0     274.0  yes
# 2          4.858     0.0    1.0  0.0       0.0     167.0   no
# 3          4.120     0.0    0.0  0.0       0.0     686.0  yes
# 4          4.856     0.0    1.0  0.0       0.0     157.0   no

# %%
df2.y = df2.y.map({'yes': 1, 'no': 0})
df2.head()
# Out:
#    interest_rate  credit  march  may  previous  duration  y
# 0          1.334     0.0    1.0  0.0       0.0     117.0  0
# 1          0.767     0.0    0.0  2.0       1.0     274.0  1
# 2          4.858     0.0    1.0  0.0       0.0     167.0  0
# 3          4.120     0.0    0.0  0.0       0.0     686.0  1
# 4          4.856     0.0    1.0  0.0       0.0     157.0  0

# %%
print(df2.isnull().sum())
print(df2.shape)
# Out:
# interest_rate    0
# credit           0
# march            0
# may              0
# previous         0
# duration         0
# y                0
# dtype: int64
# (518, 7)

# %%
df2.dtypes
# Out:
# interest_rate    float64
# credit           float64
# march            float64
# may              float64
# previous         float64
# duration         float64
# y                  int64
# dtype: object

# %%
X = df2.iloc[:,:-1]
y = df2.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 99)
print(X_train)
# Out:
#      interest_rate  credit  march  may  previous  duration
# 492          4.859     0.0    1.0  0.0       0.0     619.0
# 180          4.964     0.0    0.0  0.0       0.0     345.0
# 154          4.191     0.0    0.0  0.0       0.0      58.0
# 212          0.715     0.0    0.0  0.0       0.0     854.0
# 273          4.961     0.0    0.0  0.0       0.0     107.0
# ..             ...     ...    ...  ...       ...       ...
# 197          4.962     0.0    0.0  0.0       0.0      80.0
# 68           1.040     0.0    0.0  1.0       1.0     712.0
# 168          1.313     0.0    1.0  1.0       0.0      88.0
# 185          4.962     0.0    0.0  0.0       0.0     207.0
# 35           4.860     0.0    1.0  0.0       0.0     191.0
#
# [414 rows x 6 columns]

# %%
from sklearn.linear_model import LogisticRegression
logistic = LogisticRegression(solver='lbfgs', max_iter=1000)
logistic.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
print(X_test.shape)
# Out:
# (104, 6)

# %%
plt.figure(figsize=(20,8))
plt.scatter(X_test.interest_rate,y_test,color='red',marker='*')
plt.scatter(X_test.interest_rate, logistic.predict(X_test),color='green')

# %%
logistic.score(X_test,y_test)
# Out:
# 0.8365384615384616
